# %% [markdown]
# # Random Forest for Vegetation Change Detection

# %% [markdown]
# ### Imports

# %%
import numpy as np
import sys
import os
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score, jaccard_score
sys.path.append(os.path.abspath(".."))
from image_preprocessing.image_preprocessing import load_image_pairs_labels, read_images, crop_images

# %% [markdown]
# ### Creating Training Dataset

# %%
image_paths_train = [
    ('../../Data/Antwerpen/Antwerpen_2018/JPEG2000/OMWRGB18VL_11002.jp2', '../../Data/Antwerpen/Antwerpen_2022/JPEG2000/OMWRGB22VL_11002.jp2', 8500, 7000, 4420, 6980, 3320, 5880, 256),
    ('../../Data/Leuven/Leuven_2018/JPEG2000/OMWRGB18VL_24062.jp2', '../../Data/Leuven/Leuven_2022/JPEG2000/OMWRGB22VL_24062.jp2', 8500, 7000, 3620, 6180, 2320, 4880, 256),
    ('../../Data/Kortrijk/Kortrijk_2018/JPEG2000/OMWRGB18VL_34022.jp2', '../../Data/Kortrijk/Kortrijk_2022/JPEG2000/OMWRGB22VL_34022.jp2', 8500, 7000, 2120, 4680, 1520, 4080, 256),
    ('../../Data/Brugge/Brugge_2018/JPEG2000/OMWRGB18VL_31005.jp2', '../../Data/Brugge/Brugge_2022/JPEG2000/OMWRGB22VL_31005.jp2', 8000, 6500, 4470, 7030, 2020, 4580, 256),
    ('../../Data/Hasselt/Hasselt_2018/JPEG2000/OMWRGB18VL_71022.jp2', '../../Data/Hasselt/Hasselt_2022/JPEG2000/OMWRGB22VL_71022.jp2', 8500, 7000, 2570, 5130, 3020, 5580, 256),
    ('../../Data/Mechelen/Mechelen_2018/JPEG2000/OMWRGB18VL_12025.jp2', '../../Data/Mechelen/Mechelen_2022/JPEG2000/OMWRGB22VL_12025.jp2', 8500, 7000, 3570, 6130, 3020, 5580, 256),
               ]

image_pairs_train, labels_train = load_image_pairs_labels(image_paths_train, normalized=True)

# cleanup
if 255 in np.unique(labels_train):
   labels_train = np.clip(labels_train, 0, 1).astype(np.uint8)
# Out:
# Reading ../../Data/Antwerpen/Antwerpen_2018/JPEG2000/OMWRGB18VL_11002.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Antwerpen/Antwerpen_2022/JPEG2000/OMWRGB22VL_11002.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Leuven/Leuven_2018/JPEG2000/OMWRGB18VL_24062.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Leuven/Leuven_2022/JPEG2000/OMWRGB22VL_24062.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Kortrijk/Kortrijk_2018/JPEG2000/OMWRGB18VL_34022.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Kortrijk/Kortrijk_2022/JPEG2000/OMWRGB22VL_34022.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Brugge/Brugge_2018/JPEG2000/OMWRGB18VL_31005.jp2 into shape (3, 8000, 6500)
# Reading ../../Data/Brugge/Brugge_2022/JPEG2000/OMWRGB22VL_31005.jp2 into shape (3, 8000, 6500)
# Reading ../../Data/Hasselt/Hasselt_2018/JPEG2000/OMWRGB18VL_71022.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Hasselt/Hasselt_2022/JPEG2000/OMWRGB22VL_71022.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Mechelen/Mechelen_2018/JPEG2000/OMWRGB18VL_12025.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Mechelen/Mechelen_2022/JPEG2000/OMWRGB22VL_12025.jp2 into shape (3, 8500, 7000)

# %% [markdown]
# ### Creating Testing Dataset

# %%
image_paths_test = [
    ('../../Data/Gent/Gent_2023/JPEG2000/OMWRGB23VL_44021.jp2', '../../Data/Gent/Gent_2025/JPEG2000/OMWRGB25VL_44021.jp2', 8500, 7000, 4220, 6780, 2520, 5080, 256)
               ]

image_pairs_test, labels_test = load_image_pairs_labels(image_paths_test, normalized=True)

# cleanup
if 255 in np.unique(labels_test):
   labels_test = np.clip(labels_test, 0, 1).astype(np.uint8)
# Out:
# Reading ../../Data/Gent/Gent_2023/JPEG2000/OMWRGB23VL_44021.jp2 into shape (3, 8500, 7000)
# Reading ../../Data/Gent/Gent_2025/JPEG2000/OMWRGB25VL_44021.jp2 into shape (3, 8500, 7000)

# %% [markdown]
# ### Data preparation

# %%
def prepare_rf_data(before_image, after_image, change_mask):
    """
    Convert image pair and change map into training data.
    All inputs must be (H, W, 3) and mask must be (H, W).
    """

    X1 = before_image.reshape(-1, 3)
    X2 = after_image.reshape(-1, 3)

    # Feature vector: concatenate before and after features
    X = np.concatenate([X1, X2], axis=1)  # shape: (H*W, 6)

    # Labels
    y = change_mask.reshape(-1)  # binary: 0 (no change), 1 (change)

    return X, y

# %% [markdown]
# ### Train RF

# %%
def train_random_forest(image_pairs, change_mask, n_estimators=100):
    clf = RandomForestClassifier(n_estimators=n_estimators, random_state=42)
    h, w, _ = image_pairs[0][0].shape

    for i in range(0, len(image_pairs)):
        X_train, y_train = prepare_rf_data(image_pairs[i][0], image_pairs[i][1], change_mask[i])
        clf.fit(X_train, y_train)
        print(f"model trained on image pair: ", i+1)
    
    return clf, h, w

rf_model, h, w = train_random_forest(image_pairs_train, labels_train)
# Out:
# model trained on image pair:  1
# model trained on image pair:  2
# model trained on image pair:  3
# model trained on image pair:  4
# model trained on image pair:  5
# model trained on image pair:  6
# model trained on image pair:  7
# model trained on image pair:  8
# model trained on image pair:  9
# model trained on image pair:  10
# model trained on image pair:  11
# model trained on image pair:  12
# model trained on image pair:  13
# model trained on image pair:  14
# model trained on image pair:  15
# model trained on image pair:  16
# model trained on image pair:  17
# model trained on image pair:  18
# model trained on image pair:  19
# model trained on image pair:  20
# model trained on image pair:  21
# model trained on image pair:  22
# model trained on image pair:  23
# model trained on image pair:  24
# model trained on image pair:  25
# model trained on image pair:  26
# model trained on image pair:  27
# model trained on image pair:  28
# model trained on image pair:  29
# model trained on image pair:  30
# model trained on image pair:  31
# model trained on image pair:  32
# model trained on image pair:  33
# model trained on image pair:  34
# model trained on image pair:  35
# model trained on image pair:  36
# model trained on image pair:  37
# model trained on image pair:  38
# model trained on image pair:  39
# model trained on image pair:  40
# model trained on image pair:  41
# model trained on image pair:  42
# model trained on image pair:  43
# model trained on image pair:  44
# model trained on image pair:  45
# model trained on image pair:  46
# model trained on image pair:  47
# model trained on image pair:  48
# model trained on image pair:  49
# model trained on image pair:  50
# model trained on image pair:  51
# model trained on image pair:  52
# model trained on image pair:  53
# model trained on image pair:  54
# model trained on image pair:  55
# model trained on image pair:  56
# model trained on image pair:  57
# model trained on image pair:  58
# model trained on image pair:  59
# model trained on image pair:  60
# model trained on image pair:  61
# model trained on image pair:  62
# model trained on image pair:  63
# model trained on image pair:  64
# model trained on image pair:  65
# model trained on image pair:  66
# model trained on image pair:  67
# model trained on image pair:  68
# model trained on image pair:  69
# model trained on image pair:  70
# model trained on image pair:  71
# model trained on image pair:  72
# model trained on image pair:  73
# model trained on image pair:  74
# model trained on image pair:  75
# model trained on image pair:  76
# model trained on image pair:  77
# model trained on image pair:  78
# model trained on image pair:  79
# model trained on image pair:  80
# model trained on image pair:  81
# model trained on image pair:  82
# model trained on image pair:  83
# model trained on image pair:  84
# model trained on image pair:  85
# model trained on image pair:  86
# model trained on image pair:  87
# model trained on image pair:  88
# model trained on image pair:  89
# model trained on image pair:  90
# model trained on image pair:  91
# model trained on image pair:  92
# model trained on image pair:  93
# model trained on image pair:  94
# model trained on image pair:  95
# model trained on image pair:  96
# model trained on image pair:  97
# model trained on image pair:  98
# model trained on image pair:  99
# model trained on image pair:  100
# model trained on image pair:  101
# model trained on image pair:  102
# model trained on image pair:  103
# model trained on image pair:  104
# model trained on image pair:  105
# model trained on image pair:  106
# model trained on image pair:  107
# model trained on image pair:  108
# model trained on image pair:  109
# model trained on image pair:  110
# model trained on image pair:  111
# model trained on image pair:  112
# model trained on image pair:  113
# model trained on image pair:  114
# model trained on image pair:  115
# model trained on image pair:  116
# model trained on image pair:  117
# model trained on image pair:  118
# model trained on image pair:  119
# model trained on image pair:  120
# model trained on image pair:  121
# model trained on image pair:  122
# model trained on image pair:  123
# model trained on image pair:  124
# model trained on image pair:  125
# model trained on image pair:  126
# model trained on image pair:  127
# model trained on image pair:  128
# model trained on image pair:  129
# model trained on image pair:  130
# model trained on image pair:  131
# model trained on image pair:  132
# model trained on image pair:  133
# model trained on image pair:  134
# model trained on image pair:  135
# model trained on image pair:  136
# model trained on image pair:  137
# model trained on image pair:  138
# model trained on image pair:  139
# model trained on image pair:  140
# model trained on image pair:  141
# model trained on image pair:  142
# model trained on image pair:  143
# model trained on image pair:  144
# model trained on image pair:  145
# model trained on image pair:  146
# model trained on image pair:  147
# model trained on image pair:  148
# model trained on image pair:  149
# model trained on image pair:  150
# model trained on image pair:  151
# model trained on image pair:  152
# model trained on image pair:  153
# model trained on image pair:  154
# model trained on image pair:  155
# model trained on image pair:  156
# model trained on image pair:  157
# model trained on image pair:  158
# model trained on image pair:  159
# model trained on image pair:  160
# model trained on image pair:  161
# model trained on image pair:  162
# model trained on image pair:  163
# model trained on image pair:  164
# model trained on image pair:  165
# model trained on image pair:  166
# model trained on image pair:  167
# model trained on image pair:  168
# model trained on image pair:  169
# model trained on image pair:  170
# model trained on image pair:  171
# model trained on image pair:  172
# model trained on image pair:  173
# model trained on image pair:  174
# model trained on image pair:  175
# model trained on image pair:  176
# model trained on image pair:  177
# model trained on image pair:  178
# model trained on image pair:  179
# model trained on image pair:  180
# model trained on image pair:  181
# model trained on image pair:  182
# model trained on image pair:  183
# model trained on image pair:  184
# model trained on image pair:  185
# model trained on image pair:  186
# model trained on image pair:  187
# model trained on image pair:  188
# model trained on image pair:  189
# model trained on image pair:  190
# model trained on image pair:  191
# model trained on image pair:  192
# model trained on image pair:  193
# model trained on image pair:  194
# model trained on image pair:  195
# model trained on image pair:  196
# model trained on image pair:  197
# model trained on image pair:  198
# model trained on image pair:  199
# model trained on image pair:  200
# model trained on image pair:  201
# model trained on image pair:  202
# model trained on image pair:  203
# model trained on image pair:  204
# model trained on image pair:  205
# model trained on image pair:  206
# model trained on image pair:  207
# model trained on image pair:  208
# model trained on image pair:  209
# model trained on image pair:  210
# model trained on image pair:  211
# model trained on image pair:  212
# model trained on image pair:  213
# model trained on image pair:  214
# model trained on image pair:  215
# model trained on image pair:  216
# model trained on image pair:  217
# model trained on image pair:  218
# model trained on image pair:  219
# model trained on image pair:  220
# model trained on image pair:  221
# model trained on image pair:  222
# model trained on image pair:  223
# model trained on image pair:  224
# model trained on image pair:  225
# model trained on image pair:  226
# model trained on image pair:  227
# model trained on image pair:  228
# model trained on image pair:  229
# model trained on image pair:  230
# model trained on image pair:  231
# model trained on image pair:  232
# model trained on image pair:  233
# model trained on image pair:  234
# model trained on image pair:  235
# model trained on image pair:  236
# model trained on image pair:  237
# model trained on image pair:  238
# model trained on image pair:  239
# model trained on image pair:  240
# model trained on image pair:  241
# model trained on image pair:  242
# model trained on image pair:  243
# model trained on image pair:  244
# model trained on image pair:  245
# model trained on image pair:  246
# model trained on image pair:  247
# model trained on image pair:  248
# model trained on image pair:  249
# model trained on image pair:  250
# model trained on image pair:  251
# model trained on image pair:  252
# model trained on image pair:  253
# model trained on image pair:  254
# model trained on image pair:  255
# model trained on image pair:  256
# model trained on image pair:  257
# model trained on image pair:  258
# model trained on image pair:  259
# model trained on image pair:  260
# model trained on image pair:  261
# model trained on image pair:  262
# model trained on image pair:  263
# model trained on image pair:  264
# model trained on image pair:  265
# model trained on image pair:  266
# model trained on image pair:  267
# model trained on image pair:  268
# model trained on image pair:  269
# model trained on image pair:  270
# model trained on image pair:  271
# model trained on image pair:  272
# model trained on image pair:  273
# model trained on image pair:  274
# model trained on image pair:  275
# model trained on image pair:  276
# model trained on image pair:  277
# model trained on image pair:  278
# model trained on image pair:  279
# model trained on image pair:  280
# model trained on image pair:  281
# model trained on image pair:  282
# model trained on image pair:  283
# model trained on image pair:  284
# model trained on image pair:  285
# model trained on image pair:  286
# model trained on image pair:  287
# model trained on image pair:  288
# model trained on image pair:  289
# model trained on image pair:  290
# model trained on image pair:  291
# model trained on image pair:  292
# model trained on image pair:  293
# model trained on image pair:  294
# model trained on image pair:  295
# model trained on image pair:  296
# model trained on image pair:  297
# model trained on image pair:  298
# model trained on image pair:  299
# model trained on image pair:  300
# model trained on image pair:  301
# model trained on image pair:  302
# model trained on image pair:  303
# model trained on image pair:  304
# model trained on image pair:  305
# model trained on image pair:  306
# model trained on image pair:  307
# model trained on image pair:  308
# model trained on image pair:  309
# model trained on image pair:  310
# model trained on image pair:  311
# model trained on image pair:  312
# model trained on image pair:  313
# model trained on image pair:  314
# model trained on image pair:  315
# model trained on image pair:  316
# model trained on image pair:  317
# model trained on image pair:  318
# model trained on image pair:  319
# model trained on image pair:  320
# model trained on image pair:  321
# model trained on image pair:  322
# model trained on image pair:  323
# model trained on image pair:  324
# model trained on image pair:  325
# model trained on image pair:  326
# model trained on image pair:  327
# model trained on image pair:  328
# model trained on image pair:  329
# model trained on image pair:  330
# model trained on image pair:  331
# model trained on image pair:  332
# model trained on image pair:  333
# model trained on image pair:  334
# model trained on image pair:  335
# model trained on image pair:  336
# model trained on image pair:  337
# model trained on image pair:  338
# model trained on image pair:  339
# model trained on image pair:  340
# model trained on image pair:  341
# model trained on image pair:  342
# model trained on image pair:  343
# model trained on image pair:  344
# model trained on image pair:  345
# model trained on image pair:  346
# model trained on image pair:  347
# model trained on image pair:  348
# model trained on image pair:  349
# model trained on image pair:  350
# model trained on image pair:  351
# model trained on image pair:  352
# model trained on image pair:  353
# model trained on image pair:  354
# model trained on image pair:  355
# model trained on image pair:  356
# model trained on image pair:  357
# model trained on image pair:  358
# model trained on image pair:  359
# model trained on image pair:  360
# model trained on image pair:  361
# model trained on image pair:  362
# model trained on image pair:  363
# model trained on image pair:  364
# model trained on image pair:  365
# model trained on image pair:  366
# model trained on image pair:  367
# model trained on image pair:  368
# model trained on image pair:  369
# model trained on image pair:  370
# model trained on image pair:  371
# model trained on image pair:  372
# model trained on image pair:  373
# model trained on image pair:  374
# model trained on image pair:  375
# model trained on image pair:  376
# model trained on image pair:  377
# model trained on image pair:  378
# model trained on image pair:  379
# model trained on image pair:  380
# model trained on image pair:  381
# model trained on image pair:  382
# model trained on image pair:  383
# model trained on image pair:  384
# model trained on image pair:  385
# model trained on image pair:  386
# model trained on image pair:  387
# model trained on image pair:  388
# model trained on image pair:  389
# model trained on image pair:  390
# model trained on image pair:  391
# model trained on image pair:  392
# model trained on image pair:  393
# model trained on image pair:  394
# model trained on image pair:  395
# model trained on image pair:  396
# model trained on image pair:  397
# model trained on image pair:  398
# model trained on image pair:  399
# model trained on image pair:  400
# model trained on image pair:  401
# model trained on image pair:  402
# model trained on image pair:  403
# model trained on image pair:  404
# model trained on image pair:  405
# model trained on image pair:  406
# model trained on image pair:  407
# model trained on image pair:  408
# model trained on image pair:  409
# model trained on image pair:  410
# model trained on image pair:  411
# model trained on image pair:  412
# model trained on image pair:  413
# model trained on image pair:  414
# model trained on image pair:  415
# model trained on image pair:  416
# model trained on image pair:  417
# model trained on image pair:  418
# model trained on image pair:  419
# model trained on image pair:  420
# model trained on image pair:  421
# model trained on image pair:  422
# model trained on image pair:  423
# model trained on image pair:  424
# model trained on image pair:  425
# model trained on image pair:  426
# model trained on image pair:  427
# model trained on image pair:  428
# model trained on image pair:  429
# model trained on image pair:  430
# model trained on image pair:  431
# model trained on image pair:  432
# model trained on image pair:  433
# model trained on image pair:  434
# model trained on image pair:  435
# model trained on image pair:  436
# model trained on image pair:  437
# model trained on image pair:  438
# model trained on image pair:  439
# model trained on image pair:  440
# model trained on image pair:  441
# model trained on image pair:  442
# model trained on image pair:  443
# model trained on image pair:  444
# model trained on image pair:  445
# model trained on image pair:  446
# model trained on image pair:  447
# model trained on image pair:  448
# model trained on image pair:  449
# model trained on image pair:  450
# model trained on image pair:  451
# model trained on image pair:  452
# model trained on image pair:  453
# model trained on image pair:  454
# model trained on image pair:  455
# model trained on image pair:  456
# model trained on image pair:  457
# model trained on image pair:  458
# model trained on image pair:  459
# model trained on image pair:  460
# model trained on image pair:  461
# model trained on image pair:  462
# model trained on image pair:  463
# model trained on image pair:  464
# model trained on image pair:  465
# model trained on image pair:  466
# model trained on image pair:  467
# model trained on image pair:  468
# model trained on image pair:  469
# model trained on image pair:  470
# model trained on image pair:  471
# model trained on image pair:  472
# model trained on image pair:  473
# model trained on image pair:  474
# model trained on image pair:  475
# model trained on image pair:  476
# model trained on image pair:  477
# model trained on image pair:  478
# model trained on image pair:  479
# model trained on image pair:  480
# model trained on image pair:  481
# model trained on image pair:  482
# model trained on image pair:  483
# model trained on image pair:  484
# model trained on image pair:  485
# model trained on image pair:  486
# model trained on image pair:  487
# model trained on image pair:  488
# model trained on image pair:  489
# model trained on image pair:  490
# model trained on image pair:  491
# model trained on image pair:  492
# model trained on image pair:  493
# model trained on image pair:  494
# model trained on image pair:  495
# model trained on image pair:  496
# model trained on image pair:  497
# model trained on image pair:  498
# model trained on image pair:  499
# model trained on image pair:  500
# model trained on image pair:  501
# model trained on image pair:  502
# model trained on image pair:  503
# model trained on image pair:  504
# model trained on image pair:  505
# model trained on image pair:  506
# model trained on image pair:  507
# model trained on image pair:  508
# model trained on image pair:  509
# model trained on image pair:  510
# model trained on image pair:  511
# model trained on image pair:  512
# model trained on image pair:  513
# model trained on image pair:  514
# model trained on image pair:  515
# model trained on image pair:  516
# model trained on image pair:  517
# model trained on image pair:  518
# model trained on image pair:  519
# model trained on image pair:  520
# model trained on image pair:  521
# model trained on image pair:  522
# model trained on image pair:  523
# model trained on image pair:  524
# model trained on image pair:  525
# model trained on image pair:  526
# model trained on image pair:  527
# model trained on image pair:  528
# model trained on image pair:  529
# model trained on image pair:  530
# model trained on image pair:  531
# model trained on image pair:  532
# model trained on image pair:  533
# model trained on image pair:  534
# model trained on image pair:  535
# model trained on image pair:  536
# model trained on image pair:  537
# model trained on image pair:  538
# model trained on image pair:  539
# model trained on image pair:  540
# model trained on image pair:  541
# model trained on image pair:  542
# model trained on image pair:  543
# model trained on image pair:  544
# model trained on image pair:  545
# model trained on image pair:  546
# model trained on image pair:  547
# model trained on image pair:  548
# model trained on image pair:  549
# model trained on image pair:  550
# model trained on image pair:  551
# model trained on image pair:  552
# model trained on image pair:  553
# model trained on image pair:  554
# model trained on image pair:  555
# model trained on image pair:  556
# model trained on image pair:  557
# model trained on image pair:  558
# model trained on image pair:  559
# model trained on image pair:  560
# model trained on image pair:  561
# model trained on image pair:  562
# model trained on image pair:  563
# model trained on image pair:  564
# model trained on image pair:  565
# model trained on image pair:  566
# model trained on image pair:  567
# model trained on image pair:  568
# model trained on image pair:  569
# model trained on image pair:  570
# model trained on image pair:  571
# model trained on image pair:  572
# model trained on image pair:  573
# model trained on image pair:  574
# model trained on image pair:  575
# model trained on image pair:  576
# model trained on image pair:  577
# model trained on image pair:  578
# model trained on image pair:  579
# model trained on image pair:  580
# model trained on image pair:  581
# model trained on image pair:  582
# model trained on image pair:  583
# model trained on image pair:  584
# model trained on image pair:  585
# model trained on image pair:  586
# model trained on image pair:  587
# model trained on image pair:  588
# model trained on image pair:  589
# model trained on image pair:  590
# model trained on image pair:  591
# model trained on image pair:  592
# model trained on image pair:  593
# model trained on image pair:  594
# model trained on image pair:  595
# model trained on image pair:  596
# model trained on image pair:  597
# model trained on image pair:  598
# model trained on image pair:  599
# model trained on image pair:  600

# %% [markdown]
# ### Test RF

# %%
def predict_and_visualize(clf, image_pairs, change_mask, h, w):
    acc = 0
    prec = 0
    rec = 0
    iou = 0
    f1 = 0
    for i in range(0, len(image_pairs)):
        X_test, y_true = prepare_rf_data(image_pairs[i][0], image_pairs[i][1], change_mask[i])
        y_pred = clf.predict(X_test)
        y_pred_img = y_pred.reshape(h, w)

        # print(f"Evaluating pair: ", i+1)
        # print(classification_report(y_test, y_pred))

        # plt.figure(figsize=(12, 4))
        # plt.subplot(1, 3, 1)
        # plt.imshow(y_test.reshape(h, w), cmap='gray')
        # plt.title("Ground Truth")

        # plt.subplot(1, 3, 2)
        # plt.imshow(y_pred_img, cmap='gray')
        # plt.title("Predicted Change Map")

        # plt.subplot(1, 3, 3)
        # plt.imshow(y_test.reshape(h, w) != y_pred_img, cmap='Reds')
        # plt.title("Errors")

        # plt.tight_layout()
        # plt.show()

        acc += accuracy_score(y_true, y_pred)
        prec += precision_score(y_true, y_pred, zero_division=0)
        rec += recall_score(y_true, y_pred, zero_division=0)
        iou += jaccard_score(y_true, y_pred, zero_division=0)
        f1 += f1_score(y_true, y_pred, zero_division=0)

    acc = acc/len(image_pairs)
    prec = prec/len(image_pairs)
    rec = rec/len(image_pairs)
    iou = iou/len(image_pairs)
    f1 = f1/len(image_pairs)


    return {
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "IoU": iou,
        "f1": f1
    }, y_pred, y_true


metrics, y_pred, y_true = predict_and_visualize(rf_model, image_pairs_test, labels_test, h, w)

for name, value in metrics.items():
    print(f"{name}: {value:.4f}")
# Out:
# Accuracy: 0.8515
# Precision: 0.2909
# Recall: 0.3018
# IoU: 0.1684
# f1: 0.2844
